# %%
# %matplotlib inline

import pymongo
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from tqdm import tqdm
import talib
import gc
from typing import Union

# %%
class Chast:

    def __init__(self, client, db_name='Fields'):
        self.client = client
        self.db = client[db_name]
        self._config()
        self.data = dict()
        self.results = dict()
        self.initial_capital = 100000000
        
    def _config(self):
        # 設定繪圖、TQDM讀取條、小數點位數、顯示視窗長度
        pd.options.plotting.backend = "matplotlib"
        tqdm.pandas(desc="progress-bar")
        plt.rcParams['font.family'] = ['Microsoft JhengHei'] # 中文標籤
        plt.rcParams['axes.unicode_minus'] = False # 負號
        plt.rcParams['figure.figsize'] = (16,12)
        plt.rcParams.update({'font.size': 12})
        pd.set_option('display.max_rows', 200)
        pd.set_option('display.float_format', lambda x: '%.3f' % x)
        pd.options.display.float_format = '{:,.4f}'.format

    def _result(self):
        pf = self.results['PROFIT']
        com = self.results['COMMISION']
        self.results['RESULT'] = (pf - com).sum(axis=1).cumsum()

    def _maxdrawdown(self):
        se = self.results['RESULT']
        mdd = 0
        mdd_ = list()
        h = 0
        for i in se:
            if i > h:
                h = i
            mdd = i - h
            mdd_.append(mdd)
        self.results['MDD'] = pd.Series(mdd_, index=se.index, name='MDD')

    def _sharpe_ratio(self, roll: int = 120):
        """
        計算Sharpe ratio
        預設roll 120天=半年
        roll
        """
        pf = self.results['RESULT'] 
        self.results['SHARPE RATIO'] = (pf-pf.shift(1)).rolling(roll).apply(lambda x: x.mean() / x.std() if x.std() != 0 else 0, raw=True)
    
    def _holding(self):

        bs = self.results['BS']
        if '收盤價' in self.data.keys():
            holding = bs.fillna(0) * self.data['收盤價'].loc[bs.index, bs.columns] * 1000
        else:
            self.get_from_mongo('收盤價')
            holding = bs.fillna(0) * self.data['收盤價'].loc[bs.index, bs.columns] * 1000
        self.results['HOLDING'] = holding

    def _capital(self):
        self.results['CAPITAL NET'] = self.results['CAPITAL'][:-1]

    def set_result(self):
        self._result()
        self._maxdrawdown()
        self._holding()
        self._sharpe_ratio(120)
        self._capital()

    def get_chart(self):
        keys = self.results
        if 'RESULT' not in keys:
            self.set_result()
        keys = self.results
        fig ,ax = plt.subplots(8, 1, figsize=(16, 16), gridspec_kw={'height_ratios': [2, 1, 1, 1, 1, 1, 2, 1]})
        
        if 'RESULT' in keys:
            ax[0].plot(self.results['RESULT'][:-1])
            ax[0].set_title(f'累計損益')
            ax[0].grid(True)
            ax[0].yaxis.set_major_formatter('{x:,.0f}')
            ax[0].xaxis.set_minor_locator(mdates.YearLocator())
        if 'MDD' in keys:
            ax[1].plot(self.results['MDD'][:-1], color='orange')
            ax[1].grid(True)
            ax[1].set_title('MaxDrawdown')
            ax[1].yaxis.set_major_formatter('{x:,.0f}')
        if 'BS' in keys:
            ax[2].plot(self.results['BS'].fillna(0).astype(bool).sum(axis=1)[:-1], color='green')
            ax[2].set_title('累計股數')
        if 'HOLDING' in keys:
            ax[3].plot(self.results['HOLDING'].sum(axis=1)[:-1], color='lightgreen')
            ax[3].set_title('累計市值')
            ax[3].yaxis.set_major_formatter('{x:,.0f}')
        if 'SHARPE RATIO' in keys:
            ax[4].plot(self.results['SHARPE RATIO'][:-1], color='lightblue')
            ax[4].grid(True)
            ax[4].set_title('Rolling Sharpe Ratio')
            ax[4].yaxis.set_major_formatter('{x:.3f}')
        if 'CAPITAL' in keys:
            ax[5].plot(self.results['CAPITAL NET'][:-1], color='darkgreen')
            ax[5].grid(True)
            ax[5].set_title('Capital')
            ax[5].yaxis.set_major_formatter('{x:,.0f}')
        if 'HEDGE' in keys:
            ax[6].plot(self.results['RESULT'] + self.results['HEDGE'].cumsum())
            ax[6].grid(True)
            ax[6].set_title('避險後損益')
            ax[6].yaxis.set_major_formatter('{x:,.0f}')
            ax[7].plot(self.results['HEDGE'].cumsum())
            ax[7].grid(True)
            ax[7].set_title('避險單獨損益')
            ax[7].yaxis.set_major_formatter('{x:,.0f}')

        fig.tight_layout()
        plt.show()        

    def get_from_mongo(self, elements, nodate: bool=False,
     start: Union[datetime.datetime, None]=None, 
     end: Union[datetime.datetime, None]=None):
        """
        elements: Element, 表示要在Mongo中抓哪些資料, 可用list包起來好幾項
        start: 開始時間
        end: 結束時間
        """
        if type(elements) != list:
            if elements not in self.data:
                if nodate:
                    self.data[elements] = pd.DataFrame(self.db[elements].find({}, {'_id': 0}))
                else:
                    self.data[elements] = pd.DataFrame(self.db[elements].find({"日期": {'$gt': start, '$lt': end}}, {'_id': 0})).set_index('日期')
        else:
            for e in elements:
                if e not in self.data:
                    if nodate:
                        self.data[e] = pd.DataFrame(self.db[e].find({}, {'_id': 0}))
                    else:
                        self.data[e] = pd.DataFrame(self.db[e].find({"日期": {'$gt': start, '$lt': end}}, {'_id': 0})).set_index('日期')

    def set_data(self, name: str, df: pd.DataFrame):
        """
        name: 指定data名稱
        data: 放入data
        """
        self.data[name] = df
    
    def set_result(self, pf: pd.DataFrame, bs: pd.DataFrame, com: pd.DataFrame, ep: pd.DataFrame, ed: pd.DataFrame, ca: pd.Series, hedge: pd.Series=None, hbs: pd.Series=None):
        """
        pf: 損益明細
        bs: 部位明細
        com: 費用明細
        ep: 進場價格明細
        ed: 進場時間明細
        ca: 剩餘資金變化
        hedge: 避險損益
        """
        self.results['PROFIT'] = pf
        self.results['BS'] = bs
        self.results['COMMISION'] = com
        self.results['ENTRY PRICE'] = ep
        self.results['ENTRY DATE'] = ed
        self.results['CAPITAL'] = ca
        if hedge != None:
            self.results['HEDGE'] = hedge
        if hbs != None:
            self.results['HBS'] = hbs
        
    def creat_to_daily(self, df: pd.DataFrame):
        n = pd.DataFrame(columns=self.data['還原收盤價'].columns, index=self.data['還原收盤價'].index.union(df.index))
        for i in df.index:
            for c in df.columns:
                n.at[i, str(c)] = df.at[i, c]
        return n.fillna(method='ffill')

# %%
from IPython.display import display
client = pymongo.MongoClient()
chast = Chast(client, 'Fields')
index = Chast(client, 'Index')

# %% [markdown]
# ### <font color=osheet.range> 策略步驟 </font>
# * 1. 下載需要的資料
# * 2. 設定要用到的資料，時間點要對齊收盤
# * 3.

# %% [markdown]
# ##### 1. 下載需要的資料

# %%
getting_list = [
    '還原開盤價', '還原最高價', '還原最低價', '還原收盤價', '收盤價', '成交金額(千)', '總市值(億)', '漲幅(%)'
]
start = datetime.datetime(2016, 1, 1)
# end = datetime.datetime(2022, 10, 11)
end = datetime.datetime.today()
chast.get_from_mongo(getting_list, start=start, end=end)

index_list = [
    'TWA00', 'VIX'
]
index.get_from_mongo(index_list, start=start, end=end)
index.get_from_mongo('產業名稱', nodate=True)

# %% [markdown]
# ##### 2. 設定要用到的資料

# %% [markdown]
# ##### 將各產業分開來，並且計算每天的漲跌

# %%
index.data['產業名稱']['股票代號'] = index.data['產業名稱']['股票代號'].astype(str)
close = {}
value = {}

for i in index.data['產業名稱']['產業名稱'].unique():
    ticker = index.data['產業名稱'][index.data['產業名稱']['產業名稱'] == i]['股票代號']
    close[i] = chast.data['還原收盤價'].loc[:, ticker]
    se1 = chast.data['總市值(億)'].loc[:, ticker].sum(axis=1)
    se1.name = '總市值(億)'
    se2 = chast.data['成交金額(千)'].loc[:, ticker].sum(axis=1)
    se2.name = '成交金額(千)'
    value[i] = pd.concat([se1, se2], axis=1)

# %% [markdown]
# ##### 現在我擁有各產業的市值累計值，直接以這個資料來測試簡單突破

# %%
from __future__ import (absolute_import, division, print_function, unicode_literals)
import backtrader as bt

class Strategy(bt.Strategy):
    params = dict(
        stdlen=24,
        malen=24,
    )
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))
    
    def __init__(self):
        std = [bt.ind.StdDev(d, period=self.p.stdlen) for d in self.datas]
        ma = [bt.ind.MovingAverageSimple(d, period=self.p.malen) for d in self.datas]
        self.crossover = {d: d.close > (m+s) for d, m, s in zip(self.datas, ma, std)}
        self.crossunder = {d: d.close < (m-s) for d, m, s in zip(self.datas, ma, std)}
        self.order = None
        self.buyprice = None
        self.buycomm = None

    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % 
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                    
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm

            else:
                self.log(
                    'SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % 
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

            self.bar_executed = len(self)
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def nodify_trade(self, trade):
        if not trade.isclosed:
            return
        
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                (trade.pnl, trade.pnlcomm))


    def next(self):
        # self.log('Close,%s %.2f' % (self.data._name, self.dataclose[0]))

        if self.order:
            return
        crossover = {d for d, v in self.crossover.items() if v}
        crossunder = {d for d, v in self.crossunder.items() if v}

        posdata = [d for d, pos in self.getpositions().items() if pos]

        for d in (d for d in crossover if d not in posdata):
            self.log('BUY CREATE, %s %.2f' % (d._name, d.close[0]))
            self.order = self.buy(d, size=int(self.broker.get_cash()/d.close/50))

        for d in (d for d in posdata if d in crossunder):
            self.log('SELL CREATE, %s %.2f' % (d._name, d.close[0]))
            self.order = self.sell(d)

class feed_data(bt.feeds.PandasData):
    params = (
        ('close', 0),
        ('volume', 1),
        ('open', 0),
        ('high', -1),
        ('low', -1),
        ('openinterest', -1)
    )

if __name__ == '__main__':
    cerebro = bt.Cerebro(stdstats=True)
    cerebro.addstrategy(Strategy)
    
    client = pymongo.MongoClient()
    db = client['Fields']

    # Create a Data Feed
    for k, v in value.items():
        data = feed_data(dataname=v, name=k)
        # Add the Data Feed to Cerebro
        cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000000.0)
    cerebro.broker.setcommission(commission=0.002)
    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()
    #cerebro.plot(iplot=False)
    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000000.00
# 2016-02-03, BUY CREATE, 電子–通信網路 18118.00
# 2016-02-03, BUY CREATE, 電子–電腦及週邊設備 16073.10
# 2016-02-03, BUY CREATE, 貿易百貨 5083.00
# 2016-02-03, BUY CREATE, 鋼鐵工業 4775.70
# 2016-02-03, BUY CREATE, 電子–半導體 62456.50
# 2016-02-03, BUY CREATE, 電子商務 493.40
# 2016-02-03, BUY CREATE, 橡膠工業 3024.10
# 2016-02-03, BUY CREATE, 電子–電子通路 2115.10
# 2016-02-03, BUY CREATE, 文化創意 906.30
# 2016-02-03, BUY CREATE, 紡織纖維 5266.10
# 2016-02-03, BUY CREATE, 塑膠工業 14981.70
# 2016-02-03, BUY CREATE, 電器電纜 648.30
# 2016-02-15, BUY EXECUTED, Price: 18255.50, Cost: 2008105.00, Comm 4016.21
# 2016-02-15, BUY EXECUTED, Price: 16105.40, Cost: 1997069.60, Comm 3994.14
# 2016-02-15, BUY EXECUTED, Price: 5091.90, Cost: 2001116.70, Comm 4002.23
# 2016-02-15, BUY EXECUTED, Price: 4878.00, Cost: 2039004.00, Comm 4078.01
# 2016-02-15, BUY EXECUTED, Price: 62461.70, Cost: 1998774.40, Comm 3997.55
# 2016-02-15, BUY EXECUTED, Price: 489.80, Cost: 1985159.40, Comm 3970.32
# 2016-02-15, BUY EXECUTED, Price: 3030.20, Cost: 2002962.20, Comm 4005.92
# 2016-02-15, BUY EXECUTED, Price: 2130.70, Cost: 2013511.50, Comm 4027.02
# 2016-02-15, BUY EXECUTED, Price: 909.90, Cost: 2007239.40, Comm 4014.48
# 2016-02-15, BUY EXECUTED, Price: 5297.60, Cost: 2007790.40, Comm 4015.58
# 2016-02-15, BUY EXECUTED, Price: 15117.40, Cost: 2010614.20, Comm 4021.23
# 2016-02-15, BUY EXECUTED, Price: 649.40, Cost: 2002749.60, Comm 4005.50
# 2016-02-15, BUY CREATE, 食品工業 5328.10
# 2016-02-15, BUY CREATE, 其他 10850.30
# 2016-02-15, BUY CREATE, 農業科技 30.90
# 2016-02-15, BUY CREATE, 電子–光電 10744.90
# 2016-04-14, SELL EXECUTED, Price: 5070.90, Cost: 5297.60, Comm 10.14
# 2016-04-14, SELL EXECUTED, Price: 32.30, Cost: 30.70, Comm 0.06
# 2016-04-14, SELL EXECUTED, Price: 11103.60, Cost: 11182.40, Comm 22.21
# 2016-04-14, SELL EXECUTED, Price: 679.90, Cost: 639.50, Comm 1.36
# 2016-04-14, SELL EXECUTED, Price: 53.40, Cost: 51.80, Comm 0.11
# 2016-04-14, SELL EXECUTED, Price: 1622.20, Cost: 1567.40, Comm 3.24
# 2016-04-14, SELL EXECUTED, Price: -0.00, Cost: 10.50, Comm 0.00
# 2016-04-14, SELL CREATE, 貿易百貨 5122.10
# 2016-04-14, SELL CREATE, 紡織纖維 5070.90
# 2016-04-14, SELL CREATE, 農業科技 32.30
# 2016-04-14, SELL CREATE, 電子–光電 11103.60
# 2016-04-14, SELL CREATE, 電子–資訊服務 679.90
# 2016-04-14, SELL CREATE, 存託憑證 53.40
# 2016-04-14, SELL CREATE, 觀光事業 1622.20
# 2016-04-14, SELL CREATE, 管理股票 0.00
# 2016-04-15, SELL EXECUTED, Price: 5183.60, Cost: 5091.90, Comm 10.37
# 2016-04-15, SELL EXECUTED, Price: 5112.40, Cost: 5297.60, Comm 10.22
# 2016-04-15, SELL EXECUTED, Price: 32.70, Cost: 30.70, Comm 0.07
# 2016-04-15, SELL EXECUTED, Price: 11181.30, Cost: 11182.40, Comm 22.36
# 2016-04-15, SELL EXECUTED, Price: 679.90, Cost: 639.50, Comm 1.36
# 2016-04-15, SELL EXECUTED, Price: 53.30, Cost: 51.80, Comm 0.11
# 2016-04-15, SELL EXECUTED, Price: 1622.30, Cost: 1567.40, Comm 3.24
# 2016-04-15, SELL EXECUTED, Price: -0.00, Cost: 10.50, Comm 0.00
# 2016-04-15, SELL CREATE, 紡織纖維 5112.40
# 2016-04-15, SELL CREATE, 電子–光電 11181.30
# 2016-04-15, SELL CREATE, 存託憑證 53.30
# 2016-04-15, SELL CREATE, 觀光事業 1622.30
# 2016-04-15, SELL CREATE, 管理股票 0.00
# 2016-04-18, SELL EXECUTED, Price: 5047.20, Cost: 5297.60, Comm 10.09
# 2016-04-18, SELL EXECUTED, Price: 11129.00, Cost: 11182.40, Comm 22.26
# 2016-04-18, SELL EXECUTED, Price: 53.80, Cost: 51.80, Comm 0.11
# 2016-04-18, SELL EXECUTED, Price: 1614.80, Cost: 1567.40, Comm 3.23
# 2016-04-18, SELL EXECUTED, Price: -0.00, Cost: 10.50, Comm 0.00
# 2016-04-18, SELL CREATE, 紡織纖維 5047.20
# 2016-04-18, SELL CREATE, 電子–光電 11129.00
# 2016-04-18, SELL CREATE, 存託憑證 53.80
# 2016-04-18, SELL CREATE, 觀光事業 1614.80
# 2016-04-18, SELL CREATE, 管理股票 0.00
# 2016-04-19, SELL EXECUTED, Price: 5057.20, Cost: 5297.60, Comm 10.11
# 2016-04-19, SELL EXECUTED, Price: 11059.10, Cost: 11182.40, Comm 22.12
# 2016-04-19, SELL EXECUTED, Price: 54.00, Cost: 51.80, Comm 0.11
# 2016-04-25, SELL EXECUTED, Price: 526.30, Cost: 489.80, Comm 1.05
# 2016-04-25, SELL EXECUTED, Price: 5034.50, Cost: 5297.60, Comm 10.07
# 2016-04-25, SELL EXECUTED, Price: 10472.00, Cost: 11182.40, Comm 20.94
# 2016-04-25, SELL EXECUTED, Price: 19142.30, Cost: 18270.10, Comm 38.28
# 2016-04-25, SELL EXECUTED, Price: 2795.90, Cost: 2694.90, Comm 5.59
# 2016-04-25, SELL EXECUTED, Price: 4072.40, Cost: 4018.30, Comm 8.14
# 2016-04-25, SELL EXECUTED, Price: 660.50, Cost: 639.50, Comm 1.32
# 2016-04-25, SELL EXECUTED, Price: 51.90, Cost: 51.80, Comm 0.10
# 2016-04-25, SELL EXECUTED, Price: 7265.50, Cost: 8425.30, Comm 14.53
# 2016-04-25, SELL EXECUTED, Price: 1612.60, Cost: 1567.40, Comm 3.23
# 2016-04-25, SELL EXECUTED, Price: -0.00, Cost: 10.50, Comm 0.00
# 2016-04-25, SELL CREATE, 電子–電腦及週邊設備 16572.30
# 2016-04-25, SELL CREATE, 電子–半導體 66114.10
# 2016-04-25, SELL CREATE, 文化創意 1076.40
# 2016-04-25, SELL CREATE, 電子–光電 10472.00
# 2016-04-25, SELL CREATE, 電子–其他電子 19142.30
# 2016-04-25, SELL CREATE, 化學工業 2795.90
# 2016-04-25, SELL CREATE, 航運業 4072.40
# 2016-04-25, SELL CREATE, 電子–資訊服務 660.50
# 2016-04-25, SELL CREATE, 存託憑證 51.90
# 2016-04-25, SELL CREATE, 生技醫療 7265.50
# 2016-04-25, SELL CREATE, 觀光事業 1612.60
# 2016-04-26, SELL EXECUTED, Price: 16598.20, Cost: 16105.40, Comm 33.20
# 2016-04-26, SELL EXECUTED, Price: 66503.40, Cost: 62461.70, Comm 133.01
# 2016-04-26, SELL EXECUTED, Price: 1077.60, Cost: 909.90, Comm 2.16
# 2016-04-26, SELL EXECUTED, Price: 10594.80, Cost: 11182.40, Comm 21.19
# 2016-04-26, SELL EXECUTED, Price: 19166.80, Cost: 18270.10, Comm 38.33
# 2016-04-26, SELL EXECUTED, Price: 2794.30, Cost: 2694.90, Comm 5.59
# 2016-04-26, SELL EXECUTED, Price: 4099.60, Cost: 4018.30, Comm 8.20
# 2016-04-26, SELL EXECUTED, Price: 663.70, Cost: 639.50, Comm 1.33
# 2016-04-26, SELL EXECUTED, Price: 52.40, Cost: 51.80, Comm 0.10
# 2016-04-26, SELL EXECUTED, Price: 7382.40, Cost: 8425.30, Comm 14.76
# 2016-04-26, SELL EXECUTED, Price: 1610.50, Cost: 1567.40, Comm 3.22
# 2016-04-26, SELL CREATE, 電子–電腦及週邊設備 16598.20
# 2016-04-26, SELL CREATE, 文化創意 1077.60
# 2016-04-26, SELL CREATE, 電子–光電 10594.80
# 2016-04-26, SELL CREATE, 電子–其他電子 19166.80
# 2016-04-26, SELL CREATE, 化學工業 2794.30
# 2016-04-26, SELL CREATE, 電子–資訊服務 663.70
# 2016-04-26, SELL CREATE, 存託憑證 52.40
# 2016-04-26, SELL CREATE, 生技醫療 7382.40
# 2016-05-03, SELL CREATE, 存託憑證 51.20
# 2016-05-03, SELL CREATE, 電子–電子零組件 13023.10
# 2016-05-03, SELL CREATE, 生技醫療 7299.20
# 2016-05-03, SELL CREATE, 觀光事業 1606.70
# 2016-05-04, SELL EXECUTED, Price: 15771.00, Cost: 16105.40, Comm 31.54
# 2016-05-04, SELL EXECUTED, Price: 4994.30, Cost: 5091.90, Comm 9.99
# 2016-05-04, SELL EXECUTED, Price: 61961.60, Cost: 62461.70, Comm 123.92
# 2016-05-04, SELL EXECUTED, Price: 506.30, Cost: 489.80, Comm 1.01
# 2016-05-04, SELL EXECUTED, Price: 2203.90, Cost: 2130.70, Comm 4.41
# 2016-05-04, SELL EXECUTED, Price: 1032.10, Cost: 909.90, Comm 2.06
# 2016-05-04, SELL EXECUTED, Price: 4766.10, Cost: 5297.60, Comm 9.53
# 2016-05-04, SELL EXECUTED, Price: 15842.40, Cost: 15117.40, Comm 31.68
# 2016-05-04, SELL EXECUTED, Price: 10585.20, Cost: 10917.90, Comm 21.17
# 2016-05-04, SELL EXECUTED, Price: 31.90, Cost: 30.70, Comm 0.06
# 2016-05-04, SELL EXECUTED, Price: 10108.00, Cost: 11182.40, Comm 20.22
# 2016-05-04, SELL EXECUTED, Price: 4320.30, Cost: 4165.00, Comm 8.64
# 2016-05-04, SELL EXECUTED, Price: 5306.30, Cost: 5577.30, Comm 10.61
# 2016-05-04, SELL EXECUTED, Price: 18150.60, Cost: 18270.10, Comm 36.30
# 2016-05-04, SELL EXECUTED, Price: 4658.60, Cost: 4187.00, Comm 9.32
# 2016-05-04, SELL EXECUTED, Price: 646.20, Cost: 610.30, Comm 1.29
# 2016-05-04, SELL EXECUTED, Price: 2721.70, Cost: 2694.90, Comm 5.44
# 2016-05-04, SELL EXECUTED, Price: 3919.10, Cost: 4018.30, Comm 7.84
# 2016-05-04, SELL EXECUTED, Price: 643.90, Cost: 639.50, Comm 1.29
# 2016-05-04, SELL EXECUTED, Price: 50.70, Cost: 51.80, Comm 0.10
# 2016-05-04, SELL EXECUTED, Price: 12786.90, Cost: 12836.10, Comm 25.57
# 2016-05-04, SELL EXECUTED, Price: 7267.50, Cost: 8425.30, Comm 14.54
# 2016-05-04, SELL EXECUTED, Price: 1586.10, Cost: 1567.40, Comm 3.17
# 2016-05-04, SELL CREATE, 電子–電腦及週邊設備 15771.00
# 2016-05-04, SELL CREATE, 貿易百貨 4994.30
# 2016-05-04, SELL CREATE, 鋼鐵工業 5401.30
# 2016-05-04, SELL CREATE, 電子–半導體 61961.60
# 2016-05-04, SELL CREATE, 電子商務 506.30
# 2016-05-04, SELL CREATE, 橡膠工業 3516.50
# 2016-05-04, SELL CREATE, 電子–電子通路 2203.90
# 2016-05-04, SELL CREATE, 文化創意 1032.10
# 2016-05-04, SELL CREATE, 紡織纖維 4766.10
# 2016-05-04, SELL CREATE, 塑膠工業 15842.40
# 2016-05-04, SELL CREATE, 電器電纜 714.00
# 2016-05-04, SELL CREATE, 其他 10585.20
# 2016-05-04, SELL CREATE, 農業科技 31.90
# 2016-05-04, SELL CREATE, 電子–光電 10108.00
# 2016-05-04, SELL CREATE, 電機機械 4320.30
# 2016-05-04, SELL CREATE, 水泥工業 2430.50
# 2016-05-04, SELL CREATE, 汽車工業 5306.30
# 2016-05-04, SELL CREATE, 電子–其他電子 18150.60
# 2016-05-04, SELL CREATE, 建材營建 4658.60
# 2016-05-04, SELL CREATE, 造紙工業 646.20
# 2016-05-04, SELL CREATE, 化學工業 2721.70
# 2016-05-04, SELL CREATE, 航運業 3919.10
# 2016-05-04, SELL CREATE, 電子–資訊服務 643.90
# 2016-05-04, SELL CREATE, 存託憑證 50.70
# 2016-05-04, SELL CREATE, 玻璃陶瓷 437.10
# 2016-05-04, SELL CREATE, 電子–電子零組件 12786.90
# 2016-05-04, SELL CREATE, 生技醫療 7267.50
# 2016-05-04, SELL CREATE, 油電燃氣 9150.00
# 2016-05-04, SELL CREATE, 觀光事業 1586.10
# 2016-05-04, SELL CREATE, 金融保險 32209.20
# 2016-05-05, SELL EXECUTED, Price: 15705.40, Cost: 16105.40, Comm 31.41
# 2016-05-05, SELL EXECUTED, Price: 5018.90, Cost: 5091.90, Comm 10.04
# 2016-05-05, SELL EXECUTED, Price: 5356.70, Cost: 4878.00, Comm 10.71
# 2016-05-05, SELL EXECUTED, Price: 62117.60, Cost: 62461.70, Comm 124.24
# 2016-05-05, SELL EXECUTED, Price: 509.70, Cost: 489.80, Comm 1.02
# 2016-05-05, SELL EXECUTED, Price: 3505.30, Cost: 3030.20, Comm 7.01
# 2016-05-05, SELL EXECUTED, Price: 2215.50, Cost: 2130.70, Comm 4.43
# 2016-05-05, SELL EXECUTED, Price: 1040.70, Cost: 909.90, Comm 2.08
# 2016-05-05, SELL EXECUTED, Price: 4760.10, Cost: 5297.60, Comm 9.52
# 2016-05-05, SELL EXECUTED, Price: 15790.00, Cost: 15117.40, Comm 31.58
# 2016-05-05, SELL EXECUTED, Price: 716.30, Cost: 649.40, Comm 1.43
# 2016-05-05, SELL EXECUTED, Price: 10647.50, Cost: 10917.90, Comm 21.30
# 2016-05-05, SELL EXECUTED, Price: 31.80, Cost: 30.70, Comm 0.06
# 2016-05-05, SELL EXECUTED, Price: 10167.10, Cost: 11182.40, Comm 20.33
# 2016-05-05, SELL EXECUTED, Price: 4350.20, Cost: 4165.00, Comm 8.70
# 2016-05-05, SELL EXECUTED, Price: 2411.50, Cost: 2311.70, Comm 4.82
# 2016-05-05, SELL EXECUTED, Price: 5373.90, Cost: 5577.30, Comm 10.75
# 2016-05-05, SELL EXECUTED, Price: 17954.10, Cost: 18270.10, Comm 35.91
# 2016-05-05, SELL EXECUTED, Price: 4649.20, Cost: 4187.00, Comm 9.30
# 2016-05-05, SELL EXECUTED, Price: 644.30, Cost: 610.30, Comm 1.29
# 2016-05-05, SELL EXECUTED, Price: 2736.40, Cost: 2694.90, Comm 5.47
# 2016-05-05, SELL EXECUTED, Price: 3868.80, Cost: 4018.30, Comm 7.74
# 2016-05-05, SELL EXECUTED, Price: 644.20, Cost: 639.50, Comm 1.29
# 2016-05-05, SELL EXECUTED, Price: 50.90, Cost: 51.80, Comm 0.10
# 2016-05-05, SELL EXECUTED, Price: 447.10, Cost: 417.10, Comm 0.89
# 2016-05-05, SELL EXECUTED, Price: 12837.50, Cost: 12836.10, Comm 25.68
# 2016-05-05, SELL EXECUTED, Price: 7250.50, Cost: 8425.30, Comm 14.50
# 2016-05-05, SELL EXECUTED, Price: 9121.90, Cost: 8612.10, Comm 18.24
# 2016-05-05, SELL EXECUTED, Price: 1584.90, Cost: 1567.40, Comm 3.17
# 2016-05-05, SELL EXECUTED, Price: 31972.10, Cost: 31792.40, Comm 63.94
# 2016-05-05, SELL CREATE, 電子–通信網路 18851.20
# 2016-05-05, SELL CREATE, 電子–電腦及週邊設備 15705.40
# 2016-05-05, SELL CREATE, 貿易百貨 5018.90
# 2016-05-05, SELL CREATE, 鋼鐵工業 5356.70
# 2016-05-05, SELL CREATE, 電子–半導體 62117.60
# 2016-05-05, SELL CREATE, 電子商務 509.70
# 2016-05-05, SELL CREATE, 橡膠工業 3505.30
# 2016-05-05, SELL CREATE, 電子–電子通路 2215.50
# 2016-05-05, SELL CREATE, 文化創意 1040.70
# 2016-05-05, SELL CREATE, 紡織纖維 4760.10
# 2016-05-05, SELL CREATE, 塑膠工業 15790.00
# 2016-05-05, SELL CREATE, 其他 10647.50
# 2016-05-05, SELL CREATE, 農業科技 31.80
# 2016-05-05, SELL CREATE, 電子–光電 10167.10
# 2016-05-05, SELL CREATE, 電機機械 4350.20
# 2016-05-05, SELL CREATE, 水泥工業 2411.50
# 2016-05-05, SELL CREATE, 汽車工業 5373.90
# 2016-05-05, SELL CREATE, 電子–其他電子 17954.10
# 2016-05-05, SELL CREATE, 建材營建 4649.20
# 2016-05-05, SELL CREATE, 造紙工業 644.30
# 2016-05-05, SELL CREATE, 化學工業 2736.40
# 2016-05-05, SELL CREATE, 航運業 3868.80
# 2016-05-05, SELL CREATE, 電子–資訊服務 644.20
# 2016-05-05, SELL CREATE, 存託憑證 50.90
# 2016-05-05, SELL CREATE, 電子–電子零組件 12837.50
# 2016-05-05, SELL CREATE, 生技醫療 7250.50
# 2016-05-05, SELL CREATE, 油電燃氣 9121.90
# 2016-05-05, SELL CREATE, 觀光事業 1584.90
# 2016-05-05, SELL CREATE, 金融保險 31972.10
# 2016-05-06, SELL EXECUTED, Price: 18844.90, Cost: 18255.50, Comm 37.69
# 2016-05-06, SELL EXECUTED, Price: 15521.90, Cost: 16105.40, Comm 31.04
# 2016-05-06, SELL EXECUTED, Price: 4980.90, Cost: 5091.90, Comm 9.96
# 2016-05-06, SELL EXECUTED, Price: 5374.60, Cost: 4878.00, Comm 10.75
# 2016-05-06, SELL EXECUTED, Price: 62027.70, Cost: 62461.70, Comm 124.06
# 2016-05-06, SELL EXECUTED, Price: 507.40, Cost: 489.80, Comm 1.01
# 2016-05-06, SELL EXECUTED, Price: 3457.10, Cost: 3030.20, Comm 6.91
# 2016-05-06, SELL EXECUTED, Price: 2203.70, Cost: 2130.70, Comm 4.41
# 2016-05-06, SELL EXECUTED, Price: 1037.70, Cost: 909.90, Comm 2.08
# 2016-05-06, SELL EXECUTED, Price: 4768.90, Cost: 5297.60, Comm 9.54
# 2016-05-06, SELL EXECUTED, Price: 15868.10, Cost: 15117.40, Comm 31.74
# 2016-05-06, SELL EXECUTED, Price: 10533.60, Cost: 10917.90, Comm 21.07
# 2016-05-06, SELL EXECUTED, Price: 31.50, Cost: 30.70, Comm 0.06
# 2016-05-06, SELL EXECUTED, Price: 10162.60, Cost: 11182.40, Comm 20.33
# 2016-05-06, SELL EXECUTED, Price: 4374.70, Cost: 4165.00, Comm 8.75
# 2016-05-06, SELL EXECUTED, Price: 2406.90, Cost: 2311.70, Comm 4.81
# 2016-05-06, SELL EXECUTED, Price: 5301.20, Cost: 5577.30, Comm 10.60
# 2016-05-06, SELL EXECUTED, Price: 17721.80, Cost: 18270.10, Comm 35.44
# 2016-05-06, SELL EXECUTED, Price: 4632.80, Cost: 4187.00, Comm 9.27
# 2016-05-06, SELL EXECUTED, Price: 644.80, Cost: 610.30, Comm 1.29
# 2016-05-06, SELL EXECUTED, Price: 2723.00, Cost: 2694.90, Comm 5.45
# 2016-05-06, SELL EXECUTED, Price: 3903.40, Cost: 4018.30, Comm 7.81
# 2016-05-06, SELL EXECUTED, Price: 645.60, Cost: 639.50, Comm 1.29
# 2016-05-06, SELL EXECUTED, Price: 50.40, Cost: 51.80, Comm 0.10
# 2016-05-06, SELL EXECUTED, Price: 12748.10, Cost: 12836.10, Comm 25.50
# 2016-05-06, SELL EXECUTED, Price: 7213.10, Cost: 8425.30, Comm 14.43
# 2016-05-06, SELL EXECUTED, Price: 9284.10, Cost: 8612.10, Comm 18.57
# 2016-05-06, SELL EXECUTED, Price: 1580.00, Cost: 1567.40, Comm 3.16
# 2016-05-06, SELL EXECUTED, Price: 31707.80, Cost: 31792.40, Comm 63.42
# 2016-05-06, SELL CREATE, 電子–通信網路 18844.90
# 2016-05-06, SELL CREATE, 電子–電腦及週邊設備 15521.90
# 2016-05-06, SELL CREATE, 貿易百貨 4980.90
# 2016-05-06, SELL CREATE, 鋼鐵工業 5374.60
# 2016-05-06, SELL CREATE, 電子–半導體 62027.70
# 2016-05-06, SELL CREATE, 電子商務 507.40
# 2016-05-06, SELL CREATE, 橡膠工業 3457.10
# 2016-05-06, SELL CREATE, 電子–電子通路 2203.70
# 2016-05-06, SELL CREATE, 文化創意 1037.70
# 2016-05-06, SELL CREATE, 紡織纖維 4768.90
# 2016-05-06, SELL CREATE, 塑膠工業 15868.10
# 2016-05-06, SELL CREATE, 其他 10533.60
# 2016-05-06, SELL CREATE, 農業科技 31.50
# 2016-05-06, SELL CREATE, 電子–光電 10162.60
# 2016-05-06, SELL CREATE, 電機機械 4374.70
# 2016-05-06, SELL CREATE, 水泥工業 2406.90
# 2016-05-06, SELL CREATE, 汽車工業 5301.20
# 2016-05-06, SELL CREATE, 電子–其他電子 17721.80
# 2016-05-06, SELL CREATE, 建材營建 4632.80
# 2016-05-06, SELL CREATE, 造紙工業 644.80
# 2016-05-06, SELL CREATE, 化學工業 2723.00
# 2016-05-06, SELL CREATE, 航運業 3903.40
# 2022-10-31, SELL EXECUTED, Price: 10567.30, Cost: 9468.70, Comm 21.13
# 2022-10-31, SELL EXECUTED, Price: 1817.00, Cost: 1567.40, Comm 3.63
# 2022-10-31, SELL CREATE, 鋼鐵工業 8951.20
# 2022-10-31, SELL CREATE, 橡膠工業 2503.70
# 2022-10-31, SELL CREATE, 電子–電子通路 4095.60
# 2022-10-31, SELL CREATE, 食品工業 7105.50
# 2022-10-31, SELL CREATE, 水泥工業 3995.80
# 2022-10-31, SELL CREATE, 航運業 13214.60
# 2022-10-31, SELL CREATE, 生技醫療 10567.30
# 2022-11-01, SELL EXECUTED, Price: 9003.40, Cost: 4878.00, Comm 18.01
# 2022-11-01, SELL EXECUTED, Price: 2538.60, Cost: 3030.20, Comm 5.08
# 2022-11-01, SELL EXECUTED, Price: 4104.30, Cost: 2130.70, Comm 8.21
# 2022-11-01, SELL EXECUTED, Price: 7163.20, Cost: 7482.10, Comm 14.33
# 2022-11-01, SELL EXECUTED, Price: 4037.50, Cost: 2311.70, Comm 8.07
# 2022-11-01, SELL EXECUTED, Price: 13104.80, Cost: 19023.90, Comm 26.21
# 2022-11-01, SELL EXECUTED, Price: 10827.10, Cost: 9468.70, Comm 21.65
# 2022-11-01, SELL CREATE, 電子–電子通路 4104.30
# 2022-11-01, SELL CREATE, 航運業 13104.80
# 2022-11-02, SELL EXECUTED, Price: 4128.80, Cost: 2130.70, Comm 8.26
# 2022-11-02, SELL EXECUTED, Price: 13192.30, Cost: 19023.90, Comm 26.38
# 2022-11-02, SELL CREATE, 電子–電子通路 4128.80
# 2022-11-03, SELL EXECUTED, Price: 4146.90, Cost: 2130.70, Comm 8.29
# 2022-11-03, SELL CREATE, 水泥工業 4000.80
# 2022-11-03, SELL CREATE, 航運業 13106.20
# 2022-11-04, SELL EXECUTED, Price: 4019.10, Cost: 2311.70, Comm 8.04
# 2022-11-04, SELL EXECUTED, Price: 13479.00, Cost: 19023.90, Comm 26.96
# 2022-11-04, SELL CREATE, 鋼鐵工業 8974.90
# 2022-11-07, SELL EXECUTED, Price: 9159.40, Cost: 4878.00, Comm 18.32
# 2022-11-07, BUY CREATE, 金融保險 54441.70
# 2022-11-08, BUY EXECUTED, Price: 54742.30, Cost: 1697011.30, Comm 3394.02
# 2022-11-08, BUY CREATE, 其他 17633.50
# 2022-11-09, BUY EXECUTED, Price: 17818.30, Cost: 1674920.20, Comm 3349.84
# 2022-11-09, BUY CREATE, 貿易百貨 6701.40
# 2022-11-09, BUY CREATE, 電子–半導體 162215.00
# 2022-11-10, BUY EXECUTED, Price: 6668.50, Cost: 1627114.00, Comm 3254.23
# 2022-11-10, BUY EXECUTED, Price: 160032.30, Cost: 1600323.00, Comm 3200.65
# 2022-11-10, BUY CREATE, 建材營建 6967.60
# 2022-11-11, BUY EXECUTED, Price: 6990.50, Cost: 1579853.00, Comm 3159.71
# Final Portfolio Value: 124836493.85

# %%
for d in cerebro.datas:
    if d._name != '水泥工業':
        d.plotinfo.plot = False

# %%
cerebro.plot(iplot=False)
# Out:
# [[<Figure size 1152x864 with 5 Axes>]]
